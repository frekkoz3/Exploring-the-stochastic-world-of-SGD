# %% [markdown]
# # Exploring the stochastic world of SGD - Neural Newtork Experiment

# %% [markdown]
# In this notebook we will try to empirically test the SGD's properties found until now using a simple Neural Network on some simple benchmark.
#
# This notebook is divided in 3 parts:
#
# 1. *Neural Network* - implementetion and discussion
# 2. *Benchmark* - discussion
# 2. *Empirical Validation* - of the desired properties

# %% [markdown]
# # Neural Network

# %% [markdown]
# ...

# %% [markdown]
# # Benchmark

# %% [markdown]
# ...

# %% [markdown]
# # Empirical Validation

# %% [markdown]
# ...

# %% [markdown]
# # Exploring the stochastic world of SGD - Theory

# %% [markdown]
# In this notebook we will discuss the formulation of the *Stochastic Gradient Descent* (SGD) and some of its variants as a *Stochastic Differential Equation* (SDE).
#
# This notebook is separated in 3 main parts:
#
# 1. *Gradient Descent and Stochastic Gradient Descent* - brief introduction
# 2. *SGD as SDE* - formal derivation
# 3. *Stochastic properties of SGD* - computation and discussion

# %% [markdown]
# # Gradient Descent and Stochastic Gradient Descent

# %% [markdown]
# ...

# %% [markdown]
# # SGD as SDE

# %% [markdown]
# ...

# %% [markdown]
# # Stochastic Properties of SGD

# %% [markdown]
# ...

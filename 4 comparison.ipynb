# %% [markdown]
# # Exploring the stochastic world of SGD - Comparison

# %% [markdown]
# In this notebook we will try to compare, both theoretically and empirically the stochastic properties of SGD agains the ones of other stochastic optimization techniques.
#
# This notebook is divided in 3 parts:
#
# 1. *Other Stochastic Optimization Techniques* - brief introduction and discussion
# 2. *Theoretical Comparison* - between SGD and the other techniques
# 2. *Empirical Comparison* - between SGD and the other techniques

# %% [markdown]
# # Other Stochastic Optimization Techniques

# %% [markdown]
# ...

# %% [markdown]
# # Theoretical Comparison

# %% [markdown]
# ...

# %% [markdown]
# # Empirical Comparison

# %% [markdown]
# ...

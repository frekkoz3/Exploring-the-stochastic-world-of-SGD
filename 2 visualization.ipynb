# %% [markdown]
# # Exploring the stochastic world of SGD - Visualization

# %% [markdown]
# In this notebook we will try to visualize the stochastic dynamics undergoing the stochastic gradient descent.
#
# To accomplish this we will plot the path taken by SGD on some *toy landscapes* and compare it with the deterministic counterpart, the *gradient descent*. In addiction we will also try to do some studies about some stochastic properties.
#
# This notebook is divided in 3 parts:
#
# 1. *Toy Landscapes* - description
# 2. *Visualization* - implementing the tool box and using it
# 3. *Stochastic Properties* - computation and discussion

# %% [markdown]
# # Toy Landscapes

# %% [markdown]
# ...

# %% [markdown]
# # Visualization

# %% [markdown]
# ...

# %% [markdown]
# # Stochastic Properties

# %% [markdown]
# ...
